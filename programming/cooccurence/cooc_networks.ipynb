# %%
from counter import counter
cc = counter('count-cooc')
# Out:
# Loading count-cooc from disk...

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
len(cc.items('t'))
# Out:
# 932

# %% [markdown]
# # the math

# %% [markdown]
# $$ \frac{ \text{count-t}(a) }{ \sum \text{count-t}(a) } = 1 $$
# $$ \sum_b{ \text{count-t.t}(a,b) } = 5 \sum \text{count-t}(a) $$
#
# $$ P( \text{b shows up after a} ) = 1 - \prod_N{ \left[ 1 - P( w_{j+N} = b | w_j = a ) \right] } $$
#
# $$ P( w_{j+N} = b | w_j = a ) = ?? $$
#
# $$ \frac{ \text{count-t.t}(a,b) }{ \text{count-t}(a) } = \sum_{N=1}^5 P( w_{j+N} = b | w_j = a ) \in [0, 5] $$

# %% [markdown]
# Now I want to measure how surprising a given connection is compared to the individual propensities.
# Something similar to // independence indicates that
#
# $$P(A \& B) = P(A) * P(B|A) = P(A) * P(B)$$
#
# Where the last equality expresses the independence assumption. The extent to which the leftmost and rightmost quantities differ is a good measure for the relevance of a single tie between events.
# So, assume $a$ and $b$ are independent events. From above we know that
#
# $$P(a \to b) = \prod_N{ \left[ 1 - P( w_{j+N} = b | w_j = a ) \right] }$$
#
# And by independence this is just
#
# $$ \prod_N{ \left[ 1 - P( w_{j+N} = b ) \right] } $$
#
# $$ P( w_{j+N} = b ) = \text{count-t}(b) * 5 $$

# %% [markdown]
# So we almost get what we want... Let's try another combo of formulas...
#
# $$ \frac{ \text{count-t.t}(a,b) }{ \text{count-t}(a) } = \sum_{N=1}^5 P( w_{j+N} = b | w_j = a ) $$
# $$ = \sum_{N=1}^5 P( w_{j+N} = b ) = \sum_{N=1}^5 \frac{ \text{count-t}(b) }{ \sum_b{\text{count-t}(b)} } = \frac{ 5 * \text{count-t}(b) }{ \sum_b{\text{count-t}(b)} }  $$
#
# By this math the relevant ratio is
#
# $$ \frac{ \text{count-t.t}(a,b) * \sum_b{\text{count-t}(b)} }{ \text{count-t}(a) * \text{count-t}(b) } = 5 $$

# %% [markdown]
# # generate the network

# %%
cc.counts.keys()
# Out:
# dict_keys([('fy',), ('t',), ('t1', 't2'), ('t1', 't2', 'fy')])

# %%
tot = cc.counts[('t',)].sum()
terms = cc.items('t')

# %%
rats = []
pairs = []

for t1 in terms:
    for t2 in terms:
        if t1 == t2:
            continue
        
        ca = cc(t=t1)
        cb = cc(t=t2)
        cab = cc(t1=t1, t2=t2)
        
        if cab < 10 or ca < 10 or cb < 10:
            continue

        rat = tot * cab / (ca * cb)
        pairs.append( (cc.ids['t'][t1], cc.ids['t'][t2]) )
        rats.append( rat )

# %%
rats = np.array(rats)

# %%
np.argwhere( rats > 250 ).shape
# Out:
# (93298, 1)

# %%
np.argwhere( rats < 250 ).shape
# Out:
# (97431, 1)

# %%
plt.hist( rats[(rats<250+400)&(rats>0)], bins=100 );

# %%
np.mean(rats)
# Out:
# 287.8448392690185

# %%
np.quantile(rats, 0.9)
# Out:
# 472.5454425269636

# %%
from random import sample

# %%
tops = np.argwhere( rats > np.quantile(rats, 0.999) ).flatten()
tops = list(tops)

for i in sample( tops, 100 ):
    ai, bi = pairs[i]
    at = [x for x,i in cc.ids['t'].items() if i==ai][0]
    bt = [x for x,i in cc.ids['t'].items() if i==bi][0]
    
    ac = cc.counts[('t',)][ai]
    bc = cc.counts[('t',)][bi]
    abc = cc.counts[('t1','t2')][(ai,bi)]
    bac = cc.counts[('t1','t2')][(bi,ai)]
    print( (at, bt, rats[i], ac, bc, abc, bac) )
# Out:
# ('mental-health', 'health', 2376.189283449588, 38, 166, 357, 229)
# ('high-school', 'family-income', 2480.990909090909, 11, 20, 13, 2)
# ('middle-class', 'social-class', 5152.827272727272, 22, 40, 108, 112)
# ('years', 'life', 2588.392067862192, 151, 178, 1657, 1678)
# ('social-class', 'lower', 3259.4394736842105, 40, 76, 236, 157)
# ('results-table', 'dependent-variables', 2999.0, 10, 14, 0, 6)
# ('significant-differences', 'dependent-variables', 3498.8333333333335, 12, 14, 14, 9)
# ('less-likely', 'two-types', 3088.6252873563217, 29, 15, 32, 13)
# ('independent-variables', 'three-times', 2332.5555555555557, 21, 12, 14, 0)
# ('john', 'cambridge-cambridge', 5351.156862745098, 34, 12, 52, 36)
# ('per-capita', 'models', 5825.994449583719, 23, 94, 300, 254)
# ('regression-analysis', 'two-sets', 2999.0, 14, 10, 10, 17)
# ('per-cent', 'men', 2559.161665416354, 62, 86, 325, 289)
# ('yale-university', 'oxford-university', 4771.136363636364, 11, 12, 15, 2)
# ('survey', 'life', 2629.8863489603514, 87, 178, 970, 1013)
# ('model-model', 'size', 2552.8524691358025, 18, 180, 0, 151)
# ('years', 'living', 2743.4560706401767, 151, 15, 148, 41)
# ('robert', 'journal-sociology', 2346.2764705882355, 34, 10, 19, 11)
# ('david', 'oxford-university', 4134.984848484848, 22, 12, 26, 5)
# ('chicago', 'chicago-press', 2632.351097178683, 58, 22, 80, 41)
# ('social-problems', 'quarterly', 3185.1448275862067, 15, 29, 33, 14)
# ('may-also', 'strongly', 2544.6060606060605, 12, 44, 32, 1)
# ('rates', 'public-health', 3180.757575757576, 22, 12, 20, 0)
# ('less-likely', 'model-model', 3619.4827586206898, 29, 18, 45, 0)
# ('presence', 'per-capita', 2240.3596837944665, 22, 23, 27, 2)
# ('social-relations', 'area', 2344.672727272727, 22, 35, 43, 17)
# ('model-model', 'model', 2438.0480178671132, 18, 199, 1, 206)
# ('per', 'per-cent', 3833.171028606208, 159, 62, 900, 840)
# ('university-press', 'cambridge-cambridge', 2462.141975308642, 81, 12, 57, 63)
# ('present-study', 'social-problems', 3786.972549019608, 17, 15, 23, 1)
# ('eds', 'cambridge-university', 2560.5497076023394, 57, 21, 73, 48)
# ('significance', 'dependent-variables', 2453.7272727272725, 33, 14, 27, 22)
# ('world-war', 'two-groups', 2732.816568047337, 13, 13, 11, 2)
# ('factor', 'pattern', 2286.366336633663, 101, 48, 264, 148)
# ('john', 'cambridge-university', 3410.627450980392, 34, 21, 58, 38)
# ('american-journal', 'journal-sociology', 2624.125, 16, 10, 10, 5)
# ('family-income', 'regression-analysis', 2249.25, 20, 14, 15, 13)
# ('national-institute', 'social-research', 2385.568181818182, 24, 11, 15, 15)
# ('social-class', 'middle-class', 5343.672727272728, 40, 22, 112, 108)
# ('eds', 'john', 2664.7461300309596, 57, 34, 123, 67)
# ('structural', 'social-sciences', 2624.125, 14, 24, 21, 0)
# ('washington', 'public-health', 2895.5862068965516, 29, 12, 24, 19)
# ('john', 'cambridge', 3471.65038845727, 34, 53, 149, 83)
# ('model-model', 'independent-variables', 2665.777777777778, 18, 21, 0, 20)
# ('hypothesis', 'per-capita', 2445.4520098441344, 53, 23, 71, 43)
# ('data-collection', 'dependent-variables', 2999.0, 15, 14, 15, 7)
# ('public-health', 'paper-presented', 3498.8333333333335, 12, 18, 18, 3)
# ('per-capita', 'resources', 4360.864734299517, 23, 36, 86, 66)
# ('models', 'control-variables', 2517.5357833655708, 94, 11, 62, 19)
# ('cambridge-cambridge', 'eds', 2885.002923976608, 12, 57, 47, 78)
# ('strongly', 'chicago-university', 2936.083916083916, 44, 13, 40, 0)
# ('david', 'cambridge-university', 2544.6060606060605, 22, 21, 28, 26)
# ('social-class', 'size', 2874.8747222222223, 40, 180, 493, 373)
# ('social-sciences', 'social-science', 3008.9966666666664, 24, 25, 43, 43)
# ('survey', 'years', 3234.3634010809164, 87, 151, 1012, 544)
# ('social-research', 'national-institute', 2385.568181818182, 11, 24, 15, 15)
# ('eds', 'paper-presented', 2250.711500974659, 57, 18, 55, 20)
# ('children', 'social-class', 2756.3979674796747, 123, 40, 323, 208)
# ('life', 'survey', 2746.4689396874596, 178, 87, 1013, 970)
# ('model-model', 'statistically-significant', 2799.0666666666666, 18, 15, 0, 0)
# ('cambridge-university', 'cambridge', 3319.6477987421385, 21, 53, 88, 102)
# ('control-variables', 'model-model', 3604.8585858585857, 11, 18, 6, 0)
# ('per-capita', 'table-shows', 2260.1159420289855, 23, 21, 26, 19)
# ('social-class', 'class', 5765.123106060606, 40, 132, 725, 532)
# ('social-movements', 'social-sciences', 2317.409090909091, 77, 24, 102, 79)
# ('model-model', 'collective-action', 3127.3522633744856, 18, 135, 4, 53)
# ('believe', 'scientific-study', 2346.5733173076924, 64, 26, 93, 0)
# ('free-press', 'social-problems', 3598.8, 14, 15, 18, 4)
# ('family', 'social-class', 2401.8681494661923, 281, 40, 643, 642)
# ('chicago-university', 'chicago-press', 2789.27972027972, 13, 22, 19, 13)
# ('present-study', 'high-school', 2245.2406417112297, 17, 11, 10, 2)
# ('two-groups', 'question', 2991.714979757085, 13, 95, 88, 67)
# ('per-cent', 'per', 3577.6262933657945, 62, 159, 840, 900)
# ('two-types', 'model-model', 4665.111111111111, 15, 18, 30, 0)
# ('american-journal', 'social-problems', 2799.0666666666666, 16, 15, 16, 11)
# ('quarterly', 'science-quarterly', 2369.115987460815, 29, 11, 18, 2)
# ('david', 'cambridge-cambridge', 2544.6060606060605, 22, 12, 16, 13)
# ('cambridge-cambridge', 'oxford-university', 3498.8333333333335, 12, 12, 12, 5)
# ('two-groups', 'table-shows', 2922.102564102564, 13, 21, 19, 10)
# ('present-study', 'free-press', 2646.176470588235, 17, 14, 15, 0)
# ('life', 'rates', 3666.805924412666, 178, 22, 342, 188)
# ('three-times', 'family-income', 3323.891666666667, 12, 20, 0, 7)
# ('cambridge-cambridge', 'john', 3704.6470588235293, 12, 34, 36, 52)
# ('per-capita', 'dependent-variable', 2738.217391304348, 23, 16, 24, 17)
# ('regression-analysis', 'final', 2799.0666666666666, 14, 30, 28, 23)
# ('mental-health', 'public-health', 3682.9824561403507, 38, 12, 40, 12)
# ('science-quarterly', 'quarterly', 3290.438871473354, 11, 29, 2, 18)
# ('david', 'yale-university', 2428.9421487603304, 22, 11, 14, 3)
# ('mean', 'class', 2246.9197746697746, 78, 132, 551, 342)
# ('cambridge-university', 'oxford-university', 3165.6111111111113, 21, 12, 19, 10)
# ('washington', 'paper-presented', 2332.5555555555557, 29, 18, 29, 17)
# ('life', 'years', 2621.1960711362453, 178, 151, 1678, 1657)
# ('develop', 'interpretation', 2294.7813765182186, 19, 52, 54, 16)
# ('middle-class', 'class', 3975.9469696969695, 22, 132, 275, 315)
# ('per-capita', 'control-variables', 4812.624505928854, 23, 11, 29, 8)
# ('eds', 'cambridge', 2598.9347898047004, 57, 53, 187, 113)
# ('journal-sociology', 'science-quarterly', 4198.6, 10, 11, 11, 1)
# ('collective-action', 'action', 2361.1174603174604, 135, 245, 1860, 1643)
# ('cambridge', 'cambridge-university', 3847.7735849056603, 53, 21, 102, 88)
# ('family-income', 'dependent-variable', 3017.74375, 20, 16, 23, 3)

# %% [markdown]
# # dump network

# %%
import networkx as nx

# %%
rats = np.array(rats)
cutoff = np.quantile(rats[rats>0], 0.995)
cutoff
# Out:
# 1299.5666666666666

# %%
G = nx.DiGraph()

edges = []

for i, r in enumerate(rats):
    if r < cutoff:
        continue
    
    ai,bi = pairs[i]
    at = [x for x,i in cc.ids['t'].items() if i==ai][0]
    bt = [x for x,i in cc.ids['t'].items() if i==bi][0]
    
    edges.append( [at,bt,r] )

G.add_weighted_edges_from(edges)

# %%
edges,weights = zip(*[((e1,e2),w) for (e1,e2),w in nx.get_edge_attributes(G,'weight').items()])

# %%
deg = np.array(list(x[1] for x in G.degree()))

# %%
np.where( deg < 3 )[0].shape
# Out:
# (148,)

# %%
G.remove_nodes_from( list(np.where( deg < 3 )[0]) )

# %%
Gcomp_nodes = list( nx.connected_components(G.to_undirected()) )[0]
Gcomp = nx.subgraph(G, Gcomp_nodes)

pos = nx.kamada_kawai_layout(Gcomp)

# %%
plt.figure(figsize=(30,30))

edges,weights = zip(*[((e1,e2),w) for (e1,e2),w in nx.get_edge_attributes(Gcomp,'weight').items()])

c = np.log(weights)
c /= c.max()

nx.draw_networkx_edges(Gcomp,pos,edgelist=edges,edge_cmap=plt.cm.autumn,edge_color=c)
nx.draw_networkx_nodes(Gcomp,pos,node_size=1)
nx.draw_networkx_labels(Gcomp,pos)
plt.show()

# %% [markdown]
# # just try outputting & use Gephi

# %%
from csv import writer

# %%
with open('second_cooc.csv', 'w', encoding='utf8') as outf:
    
    w = writer(outf)
    w.writerow(['Source', 'Target', 'Weight'])
    
    for (ti1, ti2, wt) in G.edges(data='weight'):
        w.writerow([ti1,ti2,wt])

# %% [markdown]
# Loading this coocurrence network first_cooc.csv into Gephi produced good results.
#
# + there is a cluster of single-letter words a -> d -> etc... which should be ignored
# + there are many words which show up equally in articles from a given journal (i.e. extremely high entropy across journals) which should be removed
# + there are many words which show up equally in all articles, usually regarding the flow, that can be removed
# + the window should be increased, and should be modified when terms are encountered, which are always followed by the second word of the term
# + it's actually good that a given term points strongly to a word that's contained in it (that's the immediate next word)
# + there are interpretable results already, but it's clear that 1k words just isn't enough. t1.t2 is only 24M with 1k words. It's not storage, it's only memory?
# + I also need to store fy.t1.t2
# + I need to upload the whole dataset
